# %%
import pandas as pd

# %%
data = pd.read_csv('data-cleaning/v7crimedata.csv')

# %%
data
# Out:
#        Incident UID         Agency        Incident Date  \
# 0            661987      SAN DIEGO  2021-02-18 17:40:00
# 1            793674      SAN DIEGO  2021-03-16 05:30:00
# 2            859375  NATIONAL CITY  2021-03-22 14:25:00
# 3            658884      SAN DIEGO  2021-03-24 12:00:00
# 4            721771       CARLSBAD  2021-05-04 18:54:00
# ...             ...            ...                  ...
# 53798       2335743      SAN DIEGO  2024-09-29 20:00:00
# 53799       2344705        SHERIFF  2024-09-27 19:30:00
# 53800       2332374      OCEANSIDE  2024-09-28 19:20:00
# 53801       2332703      SAN DIEGO  2024-09-30 00:56:00
# 53802       2333674      SAN DIEGO  2024-09-29 19:00:00
#
#       CIBRS Unique Offense ID CIBRS Offense Code CIBRS Offense Description  \
# 0           661987-13A-679864                13A        Aggravated Assault
# 1           793674-11A-818279                11A             Forcible Rape
# ...
