# %%
import pandas as pd
from IPython.display import HTML

# %%
df = pd.read_csv('v2crimedata.csv')

# %%
df.head()
# Out:
#    Incident UID         Agency  Incident Date CIBRS Unique Offense ID  \
# 0        661987      SAN DIEGO  2/18/21 17:40       661987-13A-679864
# 1        793674      SAN DIEGO   3/16/21 5:30       793674-11A-818279
# 2        859375  NATIONAL CITY  3/22/21 14:25       859375-11A-887268
# 3        658884      SAN DIEGO  3/24/21 12:00       658884-13B-676587
# 4        721771       CARLSBAD   5/4/21 18:54       721771-13B-743217
#
#   CIBRS Offense Code CIBRS Offense Description  Victim UID Victim Category  \
# 0                13A        Aggravated Assault      679864               I
# 1                11A             Forcible Rape      818279               I
# 2                11A             Forcible Rape      887268               I
# 3                13B            Simple Assault      676587               I
# 4                13B            Simple Assault      743217               I
#
#    Victim Age Overall Race City  Zip Code  Census Tract  \
# 0        22.0     HISPANIC  NaN   92037.0           NaN
# 1        41.0        WHITE  NaN       NaN           NaN
# 2        22.0     HISPANIC  NaN       NaN           NaN
# 3        45.0     HISPANIC  NaN       NaN           NaN
# 4        28.0     HISPANIC  NaN   92011.0           NaN
#
#                  CIBRS Status  Domestic Violence Incident
# 0  ProcessingComplete - Valid                        True
# 1  ProcessingComplete - Valid                       False
# 2  ProcessingComplete - Valid                       False
# 3  ProcessingComplete - Valid                        True
# 4  ProcessingComplete - Valid                       False

# %%
df['City'].isnull().sum()
# Out:
# 2402

# %% [markdown]
# ## Steps to cleaning city column:
# - For rows that have 'sheriff' as city name, replace these values with null and then do one of 2 things:
#     1. Use zip code to figure out the city
#     2. Use the 'agency' column to estimate what city the incident occurred in

# %%
# replace sheriff values with null

df['City'] = df['City'].replace('SHERIFF', None)

# %%
zipcode_city_dict = {
    92037 : 'SAN DIEGO',
    92011 : 'CARLSBAD',
    92020 : 'EL CAJON',
    91942 : 'LA MESA',
    92105 : 'SAN DIEGO',
    92071 : 'SANTEE',
    92082 : 'VALLEY CENTER',
    92040 : 'LAKESIDE',
    92101 : 'SAN DIEGO',
    91977 : 'SPRING VALLEY',
    92115 : 'SAN DIEGO',
    91945 : 'LEMON GROVE',
    92113 : 'SAN DIEGO',
    92028 : 'FALLBROOK',
    92102 : 'SAN DIEGO',
    92107 : 'SAN DIEGO',
    92058 : 'OCEANSIDE',
    92054 : 'OCEANSIDE',
    92122 : 'SAN DIEGO',
    92021 : 'EL CAJON',
    92081 : 'VISTA',
    91950 : 'NATIONAL CITY',
    92173 : 'SAN YSIDRO',
    92025 : 'ESCONDIDO',
    92104 : 'SAN DIEGO',
    91932 : 'IMPERIAL BEACH',
    91910 : 'CHULA VISTA',
    92110 : 'SAN DIEGO',
    92123 : 'SAN DIEGO',
    92126 : 'SAN DIEGO',
    92064 : 'POWAY',
    92027 : 'ESCONDIDO',
    92116 : 'SAN DIEGO',
    91914 : 'CHULA VISTA',
    92114 : 'SAN DIEGO',
    92111 : 'SAN DIEGO',
    92083 : 'VISTA',
    92109 : 'SAN DIEGO',
    91911 : 'CHULA VISTA',
    92129 : 'SAN DIEGO',
    92103 : 'SAN DIEGO',
    92019 : 'EL CAJON',
    92117 : 'SAN DIEGO',
    92154 : 'SAN DIEGO',
    92024 : 'ENCINITAS',
    92069 : 'SAN MARCOS',
    92056 : 'OCEANSIDE',
    92014 : 'DEL MAR',
    92008 : 'CARLSBAD',
    92010 : 'CARLSBAD',
    91935 : 'JAMUL',
    92084 : 'VISTA',
    91905 : 'BOULEVARD',
    91978 : 'SPRING VALLEY',
    92003 : 'BONSALL',
    92139 : 'SAN DIEGO',
    91915 : 'CHULA VISTA',
    91901 : 'ALPINE',
    92078 : 'SAN MARCOS',
    92121 : 'SAN DIEGO',
    92026 : 'ESCONDIDO',
    92106 : 'SAN DIEGO',
    92124 : 'SAN DIEGO',
    92059 : 'PALA',
    91941 : 'LA MESA',
    92057 : 'OCEANSIDE',
    91906 : 'CAMPO',
    92065 : 'RAMONA',
    92128 : 'SAN DIEGO',
    92120 : 'SAN DIEGO',
    92029 : 'ESCONDIDO',
    92009 : 'CARLSBAD',
    91913 : 'CHULA VISTA',
    92130 : 'SAN DIEGO',
    92108 : 'SAN DIEGO',
    92004 : 'BORREGO SPRINGS',
    92131 : 'SAN DIEGO',
    92119 : 'SAN DIEGO',
    91902 : 'BONITA',
    91934 : 'JACUMBA',
    92075 : 'SOLANA BEACH',
    91963 : 'POTRERO',
    91917 : 'DULZURA',
    92127 : 'SAN DIEGO',
    92007 : 'CARDIFF BY THE SEA',
    92091 : 'RANCHO SANTA FE',
    92136 : 'SAN DIEGO',
    92055 : 'CAMP PENDLETON',
    91916 : 'DESCANSO',
    91962 : 'PINE VALLEY',
    92067 : 'RANCHO SANTA FE',
    92145 : 'SAN DIEGO',
    92061 : 'PAUMA VALLEY',
    92093 : 'LA JOLLA',
    91931 : 'GUATAY',
    92086 : 'WARNER SPRINGS',
    92135 : 'SAN DIEGO',
    92036 : 'JULIAN',
    92672 : 'SAN CLEMENTE',
    92140 : 'SAN DIEGO',
    92070 : 'SANTA YSABEL',
    92182 : 'SAN DIEGO',
    92066 : 'RANCHITA',
    92536 : 'AGUANGA',
    92118 : 'CORONADO',
    92134 : 'SAN DIEGO',
    92060 : 'PALOMAR MOUNTAIN',
    92161 : 'SAN DIEGO',
    92155 : 'SAN DIEGO',
    91980 : 'TECATE',
    92096 : 'SAN MARCOS',
    91948 : 'MOUNT LAGUNA'
}

# %%
# replace null city values with their corresponding zip code city

df['City'] = df.apply(
    lambda row: zipcode_city_dict.get(row['Zip Code']) if pd.isnull(row['City']) else row['City'],
    axis=1
)

df
# Out:
#        Incident UID         Agency  Incident Date CIBRS Unique Offense ID  \
# 0            661987      SAN DIEGO  2/18/21 17:40       661987-13A-679864
# 1            793674      SAN DIEGO   3/16/21 5:30       793674-11A-818279
# 2            859375  NATIONAL CITY  3/22/21 14:25       859375-11A-887268
# 3            658884      SAN DIEGO  3/24/21 12:00       658884-13B-676587
# 4            721771       CARLSBAD   5/4/21 18:54       721771-13B-743217
# ...             ...            ...            ...                     ...
# 62328       2332374      OCEANSIDE  9/28/24 19:20     2332374-13B-2045587
# 62329       2340093        SHERIFF  9/30/24 19:02     2340093-13B-2051941
# 62330       2345854       EL CAJON  9/27/24 14:15     2345854-13B-2056500
# 62331       2332703      SAN DIEGO   9/30/24 0:56     2332703-13B-2045943
# 62332       2333674      SAN DIEGO  9/29/24 19:00     2333674-13B-2046757
#
#       CIBRS Offense Code CIBRS Offense Description  Victim UID  \
# 0                    13A        Aggravated Assault      679864
# 1                    11A             Forcible Rape      818279
# 2                    11A             Forcible Rape      887268
# 3                    13B            Simple Assault      676587
# 4                    13B            Simple Assault      743217
# ...                  ...                       ...         ...
# 62328                13B            Simple Assault     2045587
# 62329                13B            Simple Assault     2051941
# 62330                13B            Simple Assault     2056500
# 62331                13B            Simple Assault     2045943
# 62332                13B            Simple Assault     2046757
#
#       Victim Category  Victim Age    Overall Race       City  Zip Code  \
# 0                   I        22.0        HISPANIC  SAN DIEGO   92037.0
# 1                   I        41.0           WHITE       None       NaN
# 2                   I        22.0        HISPANIC       None       NaN
# 3                   I        45.0        HISPANIC       None       NaN
# 4                   I        28.0        HISPANIC   CARLSBAD   92011.0
# ...               ...         ...             ...        ...       ...
# 62328               I        36.0        HISPANIC  OCEANSIDE   92054.0
# 62329               I        14.0           WHITE  ENCINITAS   92024.0
# 62330               I         8.0  MIDDLE EASTERN   EL CAJON   92021.0
# 62331               I        59.0        HISPANIC  SAN DIEGO   92113.0
# 62332               I        55.0           BLACK  SAN DIEGO   92103.0
#
#        Census Tract                CIBRS Status  Domestic Violence Incident
# 0               NaN  ProcessingComplete - Valid                        True
# 1               NaN  ProcessingComplete - Valid                       False
# 2               NaN  ProcessingComplete - Valid                       False
# 3               NaN  ProcessingComplete - Valid                        True
# 4               NaN  ProcessingComplete - Valid                       False
# ...             ...                         ...                         ...
# 62328        184.00  ProcessingComplete - Valid                        True
# 62329        171.07  ProcessingComplete - Valid                       False
# 62330        168.07  ProcessingComplete - Valid                       False
# 62331         48.00  ProcessingComplete - Valid                        True
# 62332          4.00  ProcessingComplete - Valid                        True
#
# [62333 rows x 15 columns]

# %%
# v3crimedata

df.to_csv('v3crimedata.csv', index=False)

# %%
# create download link for v3 of data

def create_download_link(filename):
    return HTML(f'<a href="{filename}" download>Download {filename}</a>')

create_download_link('v3crimedata.csv')
# Out:
# <a href="v3crimedata.csv" download>Download v3crimedata.csv</a>

# %% [markdown]
# ## next steps for 'City' column:
#
# - Add 'Beat' and 'BCS Area' columns by left joining on 'Incident UID'
# - determine which unincorporated areas can be added in to other cities, e.g. 'ESCONDIDO UNINC' can be combined with 'ESCONDIDO'

# %%
# v0 is original data that contains Beat and BCS Area columns

v0 = pd.read_csv('v0crimedata.csv')
v3 = pd.read_csv('v3crimedata.csv')

# %%
# add back in 'Beat' and 'BCS Area' columns

v0_subset = v0[['Incident UID', 'Beat', 'BCS Area']].drop_duplicates(subset='Incident UID')
v4 = v3.merge(v0_subset, on='Incident UID', how='left')

# %%
v4.City.value_counts()
# Out:
# City
# SAN DIEGO       24128
# CHULA VISTA      4982
# OCEANSIDE        4316
# ESCONDIDO        3449
# EL CAJON         3439
#                 ...
# GUATAY              5
# LA JOLLA            3
# TECATE              2
# MOUNT LAGUNA        2
# OTAY                1
# Name: count, Length: 61, dtype: int64

# %%
# mapping the unincorporated areas to cities

city_mapping = {
    'ESCONDIDO UNINC': 'ESCONDIDO',
    'LA MESA UNINC': 'LA MESA',
    'SAN MARCOS UNIN': 'SAN MARCOS',
    'VISTA UNINC': 'VISTA',
    'EL CAJON UNINC': 'EL CAJON'
}

# %%
# change unincorporated areas to corresponding cities

v4['City'] = v4['City'].replace(city_mapping)
v4['City'].value_counts()
# Out:
# City
# SAN DIEGO             24128
# CHULA VISTA            4982
# OCEANSIDE              4316
# EL CAJON               3722
# ESCONDIDO              3561
# VISTA                  2572
# NATIONAL CITY          1823
# SPRING VALLEY          1789
# SOUTH BAY              1782
# SAN MARCOS             1677
# LA MESA                1659
# CARLSBAD               1491
# SANTEE                 1354
# LAKESIDE               1008
# LEMON GROVE             928
# FALLBROOK               831
# ENCINITAS               701
# IMPERIAL BEACH          671
# RAMONA                  550
# POWAY                   528
# VALLEY CENTER           418
# ALPINE                  303
# BONITA                  152
# PALA                    136
# JAMUL                   119
# SOLANA BEACH            113
# CAMPO                   108
# BONSALL                  88
# DEL MAR                  79
# PAUMA VALLEY             69
# JULIAN                   67
# RANCHO SANTA FE          60
# BORREGO SPRINGS          50
# BOULEVARD                44
# LINCOLN ACRES            34
# PINE VALLEY              30
# CAMP PENDLETON           27
# DESCANSO                 21
# POTRERO                  20
# SANTA YSABEL             20
# DULZURA                  18
# JACUMBA                  16
# SAN YSIDRO               15
# PALOMAR MOUNTAIN         15
# WARNER SPRINGS           13
# SAN YSABEL               10
# CARDIFF BY THE SEA        7
# RANCHITA                  5
# AGUANGA                   5
# SAN CLEMENTE              5
# CORONADO                  5
# GUATAY                    5
# LA JOLLA                  3
# TECATE                    2
# MOUNT LAGUNA              2
# OTAY                      1
# Name: count, dtype: int64

# %% [markdown]
# ## next cleaning steps for 'City':
#
# - for rows where 'City' is null, see if we can add city names based on Sheriff BCS Area or Police Beat.
#     - Create dictionaries mapping BCS Areas and Police Beats to city names
#     - Zip codes will be null for some of these since we sometimes can't get that specific. City should be the primary column for determining location.

# %%
null_city_rows = v4[v4['City'].isnull()]

# %%
# Display distinct values of 'BCS Area' column where 'Agency' is equal to 'SHERIFF'

bcs_area_values = null_city_rows[null_city_rows['Agency'] == 'SHERIFF']['BCS Area'].unique()
bcs_area_values
# Out:
# array(['DETENTION FACILITY', 'OUT OF COUNTY', 'CITY OF VISTA',
#        'NON-CONTRACT CITY', 'ALPINE', 'CITY OF SAN MARCOS',
#        'NORTH COASTAL UNINC', 'IMPERIAL BEACH UNINC',
#        'CITY OF IMPERIAL BEACH', 'CITY OF ENCINITAS'], dtype=object)

# %%
beat_values = null_city_rows[null_city_rows['Agency'] != 'SHERIFF']['Beat'].unique()
beat_values
# Out:
# array([625, 999, 523,   5,   8,  99,   3, 324,  20,   2,   7, 327,  16,
#        611,   1, 541, 614, 521, 550,  23, 511, 613,   4, 243, 232, 627,
#        512, 602,  24, 721, 200, 314,   9,  13])

# %%
# map different sheriff bcs areas to corresponding zip codes

bcsarea_city_dict = {
    'CITY OF VISTA' : 'VISTA',
    'ALPINE' : 'ALPINE',
    'CITY OF SAN MARCOS' : 'SAN MARCOS',
    'IMPERIAL BEACH UNINC' : 'IMPERIAL BEACH',
    'CITY OF IMPERIAL BEACH' : 'IMPERIAL BEACH',
    'CITY OF ENCINITAS' : 'ENCINITAS'
}

# %%
v4['City'] = v4.apply(
    lambda row: bcsarea_city_dict.get(row['BCS Area']) if pd.isnull(row['City']) else row['City'],
    axis=1
)

# %%
# replacing with bcs areas gave us 9 more rows

v4['City'].isnull().sum()
# Out:
# 166

# %%
v4['Zip Code'] = v4.apply(
    lambda row: zipcode_city_dict.get(row['City']) if pd.isnull(row['Zip Code']) else row['Zip Code'],
    axis=1
)

# %%
# map different beat values to corresponding zip codes

beat_zipcode_dict = {
    625: 92110,
    523: 92101,
    324: 91942,
    327: 92115,
    611: 92106,
    541: 92101,
    614: 92107,
    521: 92101,
    511: 92113,
    613: 92107,
    243: 92145,
    232: 92128,
    627: 92103,
    512: 92113,
    602: 92129,
    721: 92154,
    314: 92119
}

# %%
v4['Zip Code'] = v4.apply(
    lambda row: beat_zipcode_dict.get(row['Beat']) if pd.isnull(row['City']) else row['Zip Code'],
    axis=1
)

v4['City'] = v4.apply(
    lambda row: zipcode_city_dict.get(row['Zip Code']) if pd.isnull(row['City']) else row['City'],
    axis=1
)

# %%
# replacing with beat gave us 24 more rows

v4['City'].isnull().sum()
# Out:
# 142

# %%
# remove the rows where BCS Area is out of the county

v4 = v4[v4['BCS Area'] != 'OUT OF COUNTY']

# %%
# deleting out of county removed 4 rows

v4[v4['City'].isnull()].shape
# Out:
# (138, 17)

# %%
v4[v4['City'].isnull()]['Agency'].unique()
# Out:
# array(['NATIONAL CITY', 'SHERIFF', 'SAN DIEGO', 'CARLSBAD', 'OCEANSIDE',
#        'LA MESA', 'ESCONDIDO', 'EL CAJON', 'HARBOR POLICE', 'CHULA VISTA'],
#       dtype=object)

# %%
agency_city_dict = {
    'NATIONAL CITY' : 'NATIONAL CITY',
    'CARLSBAD' : 'CARLSBAD',
    'OCEANSIDE' : 'OCEANSIDE',
    'LA MESA' : 'LA MESA',
    'ESCONDIDO' : 'ESCONDIDO',
    'EL CAJON' : 'EL CAJON',
    'CHULA VISTA' : 'CHULA VISTA'
}

# %%
# Fill the City column using the Agency values and the dictionary for rows where City is null

v4.loc[v4['City'].isnull(), 'City'] = v4.loc[v4['City'].isnull(), 'Agency'].map(agency_city_dict)

# %%
# filling with values from Agency gave us 60 more rows

v4['City'].isnull().sum()
# Out:
# 78

# %% [markdown]
# ## last steps for 'City' data:
#
# - look at what patterns we can find to fill in as many 'City' values as we can

# %%
# safe to assume if detention facility and beat 24, then city is Santee

v4[(v4['Beat'] == 24) & (v4['BCS Area'] == 'DETENTION FACILITY')]['City'].value_counts()
# Out:
# City
# SANTEE       405
# EL CAJON       1
# SAN DIEGO      1
# Name: count, dtype: int64

# %%
# Update the City field to 'SANTEE' for rows where City is null, BCS Area is 'DETENTION FACILITY' and Beat is 24

v4.loc[(v4['City'].isnull()) & (v4['BCS Area'] == 'DETENTION FACILITY') & (v4['Beat'] == 24), 'City'] = 'SANTEE'

# %%
# using detention facilities and beat gave us 18 more rows

v4[v4['City'].isnull()].shape
# Out:
# (60, 17)

# %%
v4[v4['City'].isnull()]
# Out:
#        Incident UID         Agency   Incident Date CIBRS Unique Offense ID  \
# 6            772344        SHERIFF    6/22/21 9:00       772344-13B-796205
# 7            773065      SAN DIEGO     7/3/21 2:00       773065-13B-796976
# 8            804854      SAN DIEGO   8/13/21 21:00       804854-13B-829961
# 17          1438067        SHERIFF   10/12/22 9:00     1438067-13A-1306213
# 21          1906077        SHERIFF    11/1/23 9:07     1906077-13B-1694149
# 48          1895587        SHERIFF   1/10/21 19:57     1895587-13B-1685125
# 179          842006      SAN DIEGO    2/1/21 12:00       842006-11D-868919
# 251         1684372      SAN DIEGO     1/1/21 0:01     1684372-11A-1513584
# 375         1684372      SAN DIEGO     1/1/21 0:01     1684372-11C-1513584
# 4724         796100      SAN DIEGO     4/1/21 0:00       796100-36B-820804
# 4883         919885      SAN DIEGO   5/14/21 12:00       919885-11C-950669
# 5687         919885      SAN DIEGO   5/14/21 12:00       919885-11B-950669
# 5699        1072767      SAN DIEGO     5/1/21 0:01     1072767-11A-1110236
# 6103         722177      SAN DIEGO   4/23/21 20:37       722177-11D-743660
# 6927         745772      SAN DIEGO   6/19/21 21:00       745772-13C-768355
# 7791         748162      SAN DIEGO    6/19/21 1:00       748162-13B-770883
# 9371        1419460        SHERIFF    7/13/21 0:01     1419460-36B-1290607
# 13549        837521      SAN DIEGO    9/19/21 9:30       837521-13A-864174
# 13948       1689551        SHERIFF  10/30/21 12:00     1689551-11D-1517538
# 16431        921721  HARBOR POLICE  12/20/21 17:55       921721-13A-952559
# 17402        930219      SAN DIEGO  12/31/21 23:45       930219-13B-961470
# 18654        959623      SAN DIEGO   1/29/22 19:00       959623-13B-992675
# 18863       1428424      SAN DIEGO    1/8/22 20:00     1428424-13A-1298092
# 21058       1951019        SHERIFF   4/19/22 18:30     1951019-13B-1731446
# 21180       1003699      SAN DIEGO   3/18/22 16:00     1003699-13B-1038662
# 21968       1001520      SAN DIEGO    3/20/22 0:01     1001520-13A-1036461
# 22702       1587893        SHERIFF   5/19/22 22:25     1587893-13A-1434776
# 23132       1433198        SHERIFF   5/11/22 10:30     1433198-13C-1301852
# 25839       1206340      SAN DIEGO   6/10/22 21:00     1206340-13A-1129387
# 26178       1298865        SHERIFF   7/23/22 13:35     1298865-13B-1210374
# 26873       1339782        SHERIFF    8/12/22 3:17     1339782-13B-1245045
# 27900       1437571        SHERIFF   8/27/22 10:48     1437571-13A-1305791
# 28399       1437571        SHERIFF   8/27/22 10:48     1437571-13A-1305790
# 28635       1333097      SAN DIEGO    9/12/22 4:14     1333097-11A-1239351
# 29862       1431856      SAN DIEGO  10/10/22 17:00     1431856-13C-1300848
# 30198       1433084      SAN DIEGO   10/1/22 18:48     1433084-13B-1301736
# 31450       1531499        SHERIFF  11/22/22 13:40     1531499-13B-1385731
# 31776       1694000      SAN DIEGO  10/29/22 23:49     1694000-11A-1521091
# 31867       1468232      SAN DIEGO   11/14/22 1:00     1468232-13A-1332180
# 32025       1531499        SHERIFF  11/22/22 13:40     1531499-13B-1385730
# 32704       2132256      SAN DIEGO  10/31/22 16:30     2132256-11D-1879608
# 32790       1531499        SHERIFF  11/22/22 13:40     1531499-13B-1385729
# 36408       1658081        SHERIFF   3/11/23 15:10     1658081-13B-1492793
# 37482       1682365      SAN DIEGO    2/28/23 0:01     1682365-13A-1512059
# 37982       1613883      SAN DIEGO    3/17/23 7:30     1613883-13B-1455500
# 40634       1706046      SAN DIEGO    5/29/23 0:00     1706046-13A-1530598
# 41214       1991068        SHERIFF    6/6/23 12:30     1991068-13B-1765352
# 41879       1985654        SHERIFF     7/5/23 9:19     1985654-13A-1760858
# 43497       1891260        SHERIFF   8/28/23 19:30     1891260-13B-1681503
# 43812       1828579      SAN DIEGO    9/6/23 14:30     1828579-36B-1630626
# 44661       1827544      SAN DIEGO   8/14/23 21:00     1827544-11A-1629648
# 45318       1803562      SAN DIEGO   8/19/23 23:00     1803562-13B-1610643
# 46994       1881065        SHERIFF   10/5/23 22:20     1881065-13A-1673020
# 49215       2273396      SAN DIEGO   12/25/23 9:00     2273396-13C-1998481
# 50912       2273396      SAN DIEGO   12/25/23 9:00     2273396-100-1998481
# 51971       2095716      SAN DIEGO   2/26/24 10:00     2095716-100-1851105
# 52992       2093592        SHERIFF   3/18/24 21:00     2093592-13A-1849246
# 54429       2114189      SAN DIEGO   3/17/24 12:00     2114189-11A-1865587
# 56923       2268203        SHERIFF   5/30/24 21:30     2268203-13A-1994581
# 62085       2347759      SAN DIEGO     9/8/24 1:00     2347759-13A-2057984
#
#       CIBRS Offense Code      CIBRS Offense Description  Victim UID  \
# 6                    13B                 Simple Assault      796205
# 7                    13B                 Simple Assault      796976
# 8                    13B                 Simple Assault      829961
# 17                   13A             Aggravated Assault     1306213
# 21                   13B                 Simple Assault     1694149
# 48                   13B                 Simple Assault     1685125
# 179                  11D              Forcible Fondling      868919
# 251                  11A                  Forcible Rape     1513584
# 375                  11C  Sexual Assault With An Object     1513584
# 4724                 36B                 Statutory Rape      820804
# 4883                 11C  Sexual Assault With An Object      950669
# 5687                 11B                Forcible Sodomy      950669
# 5699                 11A                  Forcible Rape     1110236
# 6103                 11D              Forcible Fondling      743660
# 6927                 13C                   Intimidation      768355
# 7791                 13B                 Simple Assault      770883
# 9371                 36B                 Statutory Rape     1290607
# 13549                13A             Aggravated Assault      864174
# 13948                11D              Forcible Fondling     1517538
# 16431                13A             Aggravated Assault      952559
# 17402                13B                 Simple Assault      961470
# 18654                13B                 Simple Assault      992675
# 18863                13A             Aggravated Assault     1298092
# 21058                13B                 Simple Assault     1731446
# 21180                13B                 Simple Assault     1038662
# 21968                13A             Aggravated Assault     1036461
# 22702                13A             Aggravated Assault     1434776
# 23132                13C                   Intimidation     1301852
# 25839                13A             Aggravated Assault     1129387
# 26178                13B                 Simple Assault     1210374
# 26873                13B                 Simple Assault     1245045
# 27900                13A             Aggravated Assault     1305791
# 28399                13A             Aggravated Assault     1305790
# 28635                11A                  Forcible Rape     1239351
# 29862                13C                   Intimidation     1300848
# 30198                13B                 Simple Assault     1301736
# 31450                13B                 Simple Assault     1385731
# 31776                11A                  Forcible Rape     1521091
# 31867                13A             Aggravated Assault     1332180
# 32025                13B                 Simple Assault     1385730
# 32704                11D              Forcible Fondling     1879608
# 32790                13B                 Simple Assault     1385729
# 36408                13B                 Simple Assault     1492793
# 37482                13A             Aggravated Assault     1512059
# 37982                13B                 Simple Assault     1455500
# 40634                13A             Aggravated Assault     1530598
# 41214                13B                 Simple Assault     1765352
# 41879                13A             Aggravated Assault     1760858
# 43497                13B                 Simple Assault     1681503
# 43812                36B                 Statutory Rape     1630626
# 44661                11A                  Forcible Rape     1629648
# 45318                13B                 Simple Assault     1610643
# 46994                13A             Aggravated Assault     1673020
# 49215                13C                   Intimidation     1998481
# 50912                100            Kidnaping/Abduction     1998481
# 51971                100            Kidnaping/Abduction     1851105
# 52992                13A             Aggravated Assault     1849246
# 54429                11A                  Forcible Rape     1865587
# 56923                13A             Aggravated Assault     1994581
# 62085                13A             Aggravated Assault     2057984
#
#       Victim Category  Victim Age      Overall Race City  Zip Code  \
# 6                   I         NaN             OTHER  NaN       NaN
# 7                   I        18.0          HISPANIC  NaN       NaN
# 8                   I        40.0             WHITE  NaN       NaN
# 17                  I         NaN             WHITE  NaN       NaN
# 21                  I        48.0             WHITE  NaN       NaN
# 48                  I         0.0          HISPANIC  NaN       NaN
# 179                 I        10.0             WHITE  NaN       NaN
# 251                 I        20.0             WHITE  NaN       NaN
# 375                 I        20.0             WHITE  NaN       NaN
# 4724                I        14.0             BLACK  NaN       NaN
# 4883                I         7.0             BLACK  NaN       NaN
# 5687                I         7.0             BLACK  NaN       NaN
# 5699                I        18.0             ASIAN  NaN       NaN
# 6103                I        15.0             WHITE  NaN       NaN
# 6927                I        37.0             WHITE  NaN       NaN
# 7791                I        19.0             OTHER  NaN       NaN
# 9371                I        14.0          HISPANIC  NaN       NaN
# 13549               I        29.0             WHITE  NaN       NaN
# 13948               I         9.0             BLACK  NaN       NaN
# 16431               I        43.0             WHITE  NaN       NaN
# 17402               I        47.0             WHITE  NaN       NaN
# 18654               I        31.0          HISPANIC  NaN       NaN
# 18863               I        37.0    MIDDLE EASTERN  NaN       NaN
# 21058               I         NaN             ASIAN  NaN       NaN
# 21180               I        24.0          HISPANIC  NaN       NaN
# 21968               I        32.0             WHITE  NaN       NaN
# 22702               I        56.0  PACIFIC ISLANDER  NaN       NaN
# 23132               I         NaN             WHITE  NaN       NaN
# 25839               I        52.0             BLACK  NaN       NaN
# 26178               I         1.0          HISPANIC  NaN       NaN
# 26873               I         1.0          HISPANIC  NaN       NaN
# 27900               I         NaN          HISPANIC  NaN       NaN
# 28399               I         NaN          HISPANIC  NaN       NaN
# 28635               I        24.0             WHITE  NaN       NaN
# 29862               I        26.0             BLACK  NaN       NaN
# 30198               I        21.0             WHITE  NaN       NaN
# 31450               I         NaN          HISPANIC  NaN       NaN
# 31776               I        15.0             BLACK  NaN       NaN
# 31867               I        23.0          HISPANIC  NaN       NaN
# 32025               I         NaN             WHITE  NaN       NaN
# 32704               I        18.0          HISPANIC  NaN       NaN
# 32790               I         NaN          HISPANIC  NaN       NaN
# 36408               I        46.0          HISPANIC  NaN       NaN
# 37482               I         0.0          HISPANIC  NaN       NaN
# 37982               I        54.0             WHITE  NaN       NaN
# 40634               I        36.0             WHITE  NaN       NaN
# 41214               L         NaN             WHITE  NaN       NaN
# 41879               I         NaN             OTHER  NaN       NaN
# 43497               I        22.0          HISPANIC  NaN       NaN
# 43812               I        15.0          HISPANIC  NaN       NaN
# 44661               I        16.0          HISPANIC  NaN       NaN
# 45318               I        38.0          HISPANIC  NaN       NaN
# 46994               I         NaN             OTHER  NaN       NaN
# 49215               I        33.0             WHITE  NaN       NaN
# 50912               I        33.0             WHITE  NaN       NaN
# 51971               I        17.0             BLACK  NaN       NaN
# 52992               I        36.0          HISPANIC  NaN       NaN
# 54429               I        33.0             WHITE  NaN       NaN
# 56923               I         NaN               NaN  NaN       NaN
# 62085               I        24.0          HISPANIC  NaN       NaN
#
#        Census Tract                  CIBRS Status  Domestic Violence Incident  \
# 6               NaN    ProcessingComplete - Valid                       False
# 7               NaN    ProcessingComplete - Valid                        True
# 8               NaN    ProcessingComplete - Valid                        True
# 17              NaN    ProcessingComplete - Valid                       False
# 21              NaN    ProcessingComplete - Valid                       False
# 48              NaN    ProcessingComplete - Valid                       False
# 179             NaN    ProcessingComplete - Valid                       False
# 251             NaN    ProcessingComplete - Valid                       False
# 375             NaN    ProcessingComplete - Valid                       False
# 4724            NaN    ProcessingComplete - Valid                       False
# 4883            NaN    ProcessingComplete - Valid                       False
# 5687            NaN    ProcessingComplete - Valid                       False
# 5699            NaN  ProcessingComplete - Invalid                       False
# 6103            NaN    ProcessingComplete - Valid                       False
# 6927            NaN  ProcessingComplete - Invalid                        True
# 7791            NaN    ProcessingComplete - Valid                        True
# 9371            NaN    ProcessingComplete - Valid                       False
# 13549           NaN    ProcessingComplete - Valid                       False
# 13948           NaN    ProcessingComplete - Valid                       False
# 16431           NaN    ProcessingComplete - Valid                       False
# 17402           NaN  ProcessingComplete - Invalid                        True
# 18654           NaN    ProcessingComplete - Valid                        True
# 18863           NaN  ProcessingComplete - Invalid                        True
# 21058           NaN    ProcessingComplete - Valid                       False
# 21180           NaN    ProcessingComplete - Valid                        True
# 21968           NaN    ProcessingComplete - Valid                        True
# 22702           NaN    ProcessingComplete - Valid                       False
# 23132           NaN    ProcessingComplete - Valid                       False
# 25839           NaN    ProcessingComplete - Valid                       False
# 26178           NaN    ProcessingComplete - Valid                       False
# 26873           NaN    ProcessingComplete - Valid                       False
# 27900           NaN    ProcessingComplete - Valid                       False
# 28399           NaN    ProcessingComplete - Valid                       False
# 28635           NaN    ProcessingComplete - Valid                       False
# 29862           NaN  ProcessingComplete - Invalid                        True
# 30198           NaN  ProcessingComplete - Invalid                        True
# 31450           NaN    ProcessingComplete - Valid                       False
# 31776           NaN    ProcessingComplete - Valid                       False
# 31867           NaN  ProcessingComplete - Invalid                        True
# 32025           NaN    ProcessingComplete - Valid                       False
# 32704           NaN  ProcessingComplete - Invalid                       False
# 32790           NaN    ProcessingComplete - Valid                       False
# 36408           NaN    ProcessingComplete - Valid                       False
# 37482           NaN  ProcessingComplete - Invalid                       False
# 37982           NaN  ProcessingComplete - Invalid                       False
# 40634           NaN    ProcessingComplete - Valid                        True
# 41214           NaN    ProcessingComplete - Valid                       False
# 41879           NaN    ProcessingComplete - Valid                       False
# 43497           NaN    ProcessingComplete - Valid                       False
# 43812           NaN    ProcessingComplete - Valid                       False
# 44661           NaN    ProcessingComplete - Valid                        True
# 45318           NaN  ProcessingComplete - Invalid                        True
# 46994           NaN    ProcessingComplete - Valid                       False
# 49215           NaN  ProcessingComplete - Invalid                        True
# 50912           NaN  ProcessingComplete - Invalid                        True
# 51971           NaN    ProcessingComplete - Valid                       False
# 52992           NaN  ProcessingComplete - Invalid                        True
# 54429           NaN  ProcessingComplete - Invalid                       False
# 56923           NaN    ProcessingComplete - Valid                       False
# 62085           NaN    ProcessingComplete - Valid                        True
#
#        Beat             BCS Area
# 6        29   DETENTION FACILITY
# 7       999                  NaN
# 8       999                  NaN
# 17       29   DETENTION FACILITY
# 21       29   DETENTION FACILITY
# 48        7    NON-CONTRACT CITY
# 179     999                  NaN
# 251     999                  NaN
# 375     999                  NaN
# 4724    999                  NaN
# 4883    999                  NaN
# 5687    999                  NaN
# 5699    999                  NaN
# 6103    999                  NaN
# 6927    999                  NaN
# 7791    999                  NaN
# 9371      0    NON-CONTRACT CITY
# 13549   999                  NaN
# 13948     0    NON-CONTRACT CITY
# 16431   550                  NaN
# 17402   999                  NaN
# 18654   999                  NaN
# 18863   999                  NaN
# 21058    29   DETENTION FACILITY
# 21180   999                  NaN
# 21968   999                  NaN
# 22702    21   DETENTION FACILITY
# 23132    21   DETENTION FACILITY
# 25839   999                  NaN
# 26178    29   DETENTION FACILITY
# 26873   202  NORTH COASTAL UNINC
# 27900    29   DETENTION FACILITY
# 28399    29   DETENTION FACILITY
# 28635   999                  NaN
# 29862   999                  NaN
# 30198   999                  NaN
# 31450    26   DETENTION FACILITY
# 31776   999                  NaN
# 31867   999                  NaN
# 32025    26   DETENTION FACILITY
# 32704   999                  NaN
# 32790    26   DETENTION FACILITY
# 36408    29   DETENTION FACILITY
# 37482   999                  NaN
# 37982   999                  NaN
# 40634   999                  NaN
# 41214    29   DETENTION FACILITY
# 41879    29   DETENTION FACILITY
# 43497    29   DETENTION FACILITY
# 43812   999                  NaN
# 44661   999                  NaN
# 45318   999                  NaN
# 46994    29   DETENTION FACILITY
# 49215   999                  NaN
# 50912   999                  NaN
# 51971   999                  NaN
# 52992     0    NON-CONTRACT CITY
# 54429   999                  NaN
# 56923    29   DETENTION FACILITY
# 62085   999                  NaN

# %%
# assume all rows with 'Beat' 29 are in Oceanside

v4[v4['Beat'] == 29]['City'].value_counts()
# Out:
# City
# OCEANSIDE    34
# Name: count, dtype: int64

# %%
# assume all rows with 'Beat' 202 are in Camp Pendleton

v4[v4['Beat'] == 202]['City'].value_counts()
# Out:
# City
# CAMP PENDLETON    27
# VISTA              2
# SAN CLEMENTE       1
# Name: count, dtype: int64

# %%
# add city names for beats 29 and 202

v4.loc[(v4['City'].isnull()) & (v4['Beat'] == 29), 'City'] = 'OCEANSIDE'
v4.loc[(v4['City'].isnull()) & (v4['Beat'] == 202), 'City'] = 'CAMP PENDLETON'

# %%
# adding city names for beats 29 and 202 gave us 14 more rows

v4['City'].isnull().sum()
# Out:
# 46

# %%
v4[v4['City'].isnull()]
# Out:
#        Incident UID         Agency   Incident Date CIBRS Unique Offense ID  \
# 7            773065      SAN DIEGO     7/3/21 2:00       773065-13B-796976
# 8            804854      SAN DIEGO   8/13/21 21:00       804854-13B-829961
# 48          1895587        SHERIFF   1/10/21 19:57     1895587-13B-1685125
# 179          842006      SAN DIEGO    2/1/21 12:00       842006-11D-868919
# 251         1684372      SAN DIEGO     1/1/21 0:01     1684372-11A-1513584
# 375         1684372      SAN DIEGO     1/1/21 0:01     1684372-11C-1513584
# 4724         796100      SAN DIEGO     4/1/21 0:00       796100-36B-820804
# 4883         919885      SAN DIEGO   5/14/21 12:00       919885-11C-950669
# 5687         919885      SAN DIEGO   5/14/21 12:00       919885-11B-950669
# 5699        1072767      SAN DIEGO     5/1/21 0:01     1072767-11A-1110236
# 6103         722177      SAN DIEGO   4/23/21 20:37       722177-11D-743660
# 6927         745772      SAN DIEGO   6/19/21 21:00       745772-13C-768355
# 7791         748162      SAN DIEGO    6/19/21 1:00       748162-13B-770883
# 9371        1419460        SHERIFF    7/13/21 0:01     1419460-36B-1290607
# 13549        837521      SAN DIEGO    9/19/21 9:30       837521-13A-864174
# 13948       1689551        SHERIFF  10/30/21 12:00     1689551-11D-1517538
# 16431        921721  HARBOR POLICE  12/20/21 17:55       921721-13A-952559
# 17402        930219      SAN DIEGO  12/31/21 23:45       930219-13B-961470
# 18654        959623      SAN DIEGO   1/29/22 19:00       959623-13B-992675
# 18863       1428424      SAN DIEGO    1/8/22 20:00     1428424-13A-1298092
# 21180       1003699      SAN DIEGO   3/18/22 16:00     1003699-13B-1038662
# 21968       1001520      SAN DIEGO    3/20/22 0:01     1001520-13A-1036461
# 22702       1587893        SHERIFF   5/19/22 22:25     1587893-13A-1434776
# 23132       1433198        SHERIFF   5/11/22 10:30     1433198-13C-1301852
# 25839       1206340      SAN DIEGO   6/10/22 21:00     1206340-13A-1129387
# 28635       1333097      SAN DIEGO    9/12/22 4:14     1333097-11A-1239351
# 29862       1431856      SAN DIEGO  10/10/22 17:00     1431856-13C-1300848
# 30198       1433084      SAN DIEGO   10/1/22 18:48     1433084-13B-1301736
# 31450       1531499        SHERIFF  11/22/22 13:40     1531499-13B-1385731
# 31776       1694000      SAN DIEGO  10/29/22 23:49     1694000-11A-1521091
# 31867       1468232      SAN DIEGO   11/14/22 1:00     1468232-13A-1332180
# 32025       1531499        SHERIFF  11/22/22 13:40     1531499-13B-1385730
# 32704       2132256      SAN DIEGO  10/31/22 16:30     2132256-11D-1879608
# 32790       1531499        SHERIFF  11/22/22 13:40     1531499-13B-1385729
# 37482       1682365      SAN DIEGO    2/28/23 0:01     1682365-13A-1512059
# 37982       1613883      SAN DIEGO    3/17/23 7:30     1613883-13B-1455500
# 40634       1706046      SAN DIEGO    5/29/23 0:00     1706046-13A-1530598
# 43812       1828579      SAN DIEGO    9/6/23 14:30     1828579-36B-1630626
# 44661       1827544      SAN DIEGO   8/14/23 21:00     1827544-11A-1629648
# 45318       1803562      SAN DIEGO   8/19/23 23:00     1803562-13B-1610643
# 49215       2273396      SAN DIEGO   12/25/23 9:00     2273396-13C-1998481
# 50912       2273396      SAN DIEGO   12/25/23 9:00     2273396-100-1998481
# 51971       2095716      SAN DIEGO   2/26/24 10:00     2095716-100-1851105
# 52992       2093592        SHERIFF   3/18/24 21:00     2093592-13A-1849246
# 54429       2114189      SAN DIEGO   3/17/24 12:00     2114189-11A-1865587
# 62085       2347759      SAN DIEGO     9/8/24 1:00     2347759-13A-2057984
#
#       CIBRS Offense Code      CIBRS Offense Description  Victim UID  \
# 7                    13B                 Simple Assault      796976
# 8                    13B                 Simple Assault      829961
# 48                   13B                 Simple Assault     1685125
# 179                  11D              Forcible Fondling      868919
# 251                  11A                  Forcible Rape     1513584
# 375                  11C  Sexual Assault With An Object     1513584
# 4724                 36B                 Statutory Rape      820804
# 4883                 11C  Sexual Assault With An Object      950669
# 5687                 11B                Forcible Sodomy      950669
# 5699                 11A                  Forcible Rape     1110236
# 6103                 11D              Forcible Fondling      743660
# 6927                 13C                   Intimidation      768355
# 7791                 13B                 Simple Assault      770883
# 9371                 36B                 Statutory Rape     1290607
# 13549                13A             Aggravated Assault      864174
# 13948                11D              Forcible Fondling     1517538
# 16431                13A             Aggravated Assault      952559
# 17402                13B                 Simple Assault      961470
# 18654                13B                 Simple Assault      992675
# 18863                13A             Aggravated Assault     1298092
# 21180                13B                 Simple Assault     1038662
# 21968                13A             Aggravated Assault     1036461
# 22702                13A             Aggravated Assault     1434776
# 23132                13C                   Intimidation     1301852
# 25839                13A             Aggravated Assault     1129387
# 28635                11A                  Forcible Rape     1239351
# 29862                13C                   Intimidation     1300848
# 30198                13B                 Simple Assault     1301736
# 31450                13B                 Simple Assault     1385731
# 31776                11A                  Forcible Rape     1521091
# 31867                13A             Aggravated Assault     1332180
# 32025                13B                 Simple Assault     1385730
# 32704                11D              Forcible Fondling     1879608
# 32790                13B                 Simple Assault     1385729
# 37482                13A             Aggravated Assault     1512059
# 37982                13B                 Simple Assault     1455500
# 40634                13A             Aggravated Assault     1530598
# 43812                36B                 Statutory Rape     1630626
# 44661                11A                  Forcible Rape     1629648
# 45318                13B                 Simple Assault     1610643
# 49215                13C                   Intimidation     1998481
# 50912                100            Kidnaping/Abduction     1998481
# 51971                100            Kidnaping/Abduction     1851105
# 52992                13A             Aggravated Assault     1849246
# 54429                11A                  Forcible Rape     1865587
# 62085                13A             Aggravated Assault     2057984
#
#       Victim Category  Victim Age      Overall Race City  Zip Code  \
# 7                   I        18.0          HISPANIC  NaN       NaN
# 8                   I        40.0             WHITE  NaN       NaN
# 48                  I         0.0          HISPANIC  NaN       NaN
# 179                 I        10.0             WHITE  NaN       NaN
# 251                 I        20.0             WHITE  NaN       NaN
# 375                 I        20.0             WHITE  NaN       NaN
# 4724                I        14.0             BLACK  NaN       NaN
# 4883                I         7.0             BLACK  NaN       NaN
# 5687                I         7.0             BLACK  NaN       NaN
# 5699                I        18.0             ASIAN  NaN       NaN
# 6103                I        15.0             WHITE  NaN       NaN
# 6927                I        37.0             WHITE  NaN       NaN
# 7791                I        19.0             OTHER  NaN       NaN
# 9371                I        14.0          HISPANIC  NaN       NaN
# 13549               I        29.0             WHITE  NaN       NaN
# 13948               I         9.0             BLACK  NaN       NaN
# 16431               I        43.0             WHITE  NaN       NaN
# 17402               I        47.0             WHITE  NaN       NaN
# 18654               I        31.0          HISPANIC  NaN       NaN
# 18863               I        37.0    MIDDLE EASTERN  NaN       NaN
# 21180               I        24.0          HISPANIC  NaN       NaN
# 21968               I        32.0             WHITE  NaN       NaN
# 22702               I        56.0  PACIFIC ISLANDER  NaN       NaN
# 23132               I         NaN             WHITE  NaN       NaN
# 25839               I        52.0             BLACK  NaN       NaN
# 28635               I        24.0             WHITE  NaN       NaN
# 29862               I        26.0             BLACK  NaN       NaN
# 30198               I        21.0             WHITE  NaN       NaN
# 31450               I         NaN          HISPANIC  NaN       NaN
# 31776               I        15.0             BLACK  NaN       NaN
# 31867               I        23.0          HISPANIC  NaN       NaN
# 32025               I         NaN             WHITE  NaN       NaN
# 32704               I        18.0          HISPANIC  NaN       NaN
# 32790               I         NaN          HISPANIC  NaN       NaN
# 37482               I         0.0          HISPANIC  NaN       NaN
# 37982               I        54.0             WHITE  NaN       NaN
# 40634               I        36.0             WHITE  NaN       NaN
# 43812               I        15.0          HISPANIC  NaN       NaN
# 44661               I        16.0          HISPANIC  NaN       NaN
# 45318               I        38.0          HISPANIC  NaN       NaN
# 49215               I        33.0             WHITE  NaN       NaN
# 50912               I        33.0             WHITE  NaN       NaN
# 51971               I        17.0             BLACK  NaN       NaN
# 52992               I        36.0          HISPANIC  NaN       NaN
# 54429               I        33.0             WHITE  NaN       NaN
# 62085               I        24.0          HISPANIC  NaN       NaN
#
#        Census Tract                  CIBRS Status  Domestic Violence Incident  \
# 7               NaN    ProcessingComplete - Valid                        True
# 8               NaN    ProcessingComplete - Valid                        True
# 48              NaN    ProcessingComplete - Valid                       False
# 179             NaN    ProcessingComplete - Valid                       False
# 251             NaN    ProcessingComplete - Valid                       False
# 375             NaN    ProcessingComplete - Valid                       False
# 4724            NaN    ProcessingComplete - Valid                       False
# 4883            NaN    ProcessingComplete - Valid                       False
# 5687            NaN    ProcessingComplete - Valid                       False
# 5699            NaN  ProcessingComplete - Invalid                       False
# 6103            NaN    ProcessingComplete - Valid                       False
# 6927            NaN  ProcessingComplete - Invalid                        True
# 7791            NaN    ProcessingComplete - Valid                        True
# 9371            NaN    ProcessingComplete - Valid                       False
# 13549           NaN    ProcessingComplete - Valid                       False
# 13948           NaN    ProcessingComplete - Valid                       False
# 16431           NaN    ProcessingComplete - Valid                       False
# 17402           NaN  ProcessingComplete - Invalid                        True
# 18654           NaN    ProcessingComplete - Valid                        True
# 18863           NaN  ProcessingComplete - Invalid                        True
# 21180           NaN    ProcessingComplete - Valid                        True
# 21968           NaN    ProcessingComplete - Valid                        True
# 22702           NaN    ProcessingComplete - Valid                       False
# 23132           NaN    ProcessingComplete - Valid                       False
# 25839           NaN    ProcessingComplete - Valid                       False
# 28635           NaN    ProcessingComplete - Valid                       False
# 29862           NaN  ProcessingComplete - Invalid                        True
# 30198           NaN  ProcessingComplete - Invalid                        True
# 31450           NaN    ProcessingComplete - Valid                       False
# 31776           NaN    ProcessingComplete - Valid                       False
# 31867           NaN  ProcessingComplete - Invalid                        True
# 32025           NaN    ProcessingComplete - Valid                       False
# 32704           NaN  ProcessingComplete - Invalid                       False
# 32790           NaN    ProcessingComplete - Valid                       False
# 37482           NaN  ProcessingComplete - Invalid                       False
# 37982           NaN  ProcessingComplete - Invalid                       False
# 40634           NaN    ProcessingComplete - Valid                        True
# 43812           NaN    ProcessingComplete - Valid                       False
# 44661           NaN    ProcessingComplete - Valid                        True
# 45318           NaN  ProcessingComplete - Invalid                        True
# 49215           NaN  ProcessingComplete - Invalid                        True
# 50912           NaN  ProcessingComplete - Invalid                        True
# 51971           NaN    ProcessingComplete - Valid                       False
# 52992           NaN  ProcessingComplete - Invalid                        True
# 54429           NaN  ProcessingComplete - Invalid                       False
# 62085           NaN    ProcessingComplete - Valid                        True
#
#        Beat            BCS Area
# 7       999                 NaN
# 8       999                 NaN
# 48        7   NON-CONTRACT CITY
# 179     999                 NaN
# 251     999                 NaN
# 375     999                 NaN
# 4724    999                 NaN
# 4883    999                 NaN
# 5687    999                 NaN
# 5699    999                 NaN
# 6103    999                 NaN
# 6927    999                 NaN
# 7791    999                 NaN
# 9371      0   NON-CONTRACT CITY
# 13549   999                 NaN
# 13948     0   NON-CONTRACT CITY
# 16431   550                 NaN
# 17402   999                 NaN
# 18654   999                 NaN
# 18863   999                 NaN
# 21180   999                 NaN
# 21968   999                 NaN
# 22702    21  DETENTION FACILITY
# 23132    21  DETENTION FACILITY
# 25839   999                 NaN
# 28635   999                 NaN
# 29862   999                 NaN
# 30198   999                 NaN
# 31450    26  DETENTION FACILITY
# 31776   999                 NaN
# 31867   999                 NaN
# 32025    26  DETENTION FACILITY
# 32704   999                 NaN
# 32790    26  DETENTION FACILITY
# 37482   999                 NaN
# 37982   999                 NaN
# 40634   999                 NaN
# 43812   999                 NaN
# 44661   999                 NaN
# 45318   999                 NaN
# 49215   999                 NaN
# 50912   999                 NaN
# 51971   999                 NaN
# 52992     0   NON-CONTRACT CITY
# 54429   999                 NaN
# 62085   999                 NaN

# %%
# safe to assume if detention facility and beat 21, then city is San Diego

v4[(v4['Beat'] == 21) & (v4['BCS Area'] == 'DETENTION FACILITY')]['City'].value_counts()
# Out:
# City
# SAN DIEGO    34
# Name: count, dtype: int64

# %%
# safe to assume if detention facility and beat 26, then city is Vista

v4[(v4['Beat'] == 26) & (v4['BCS Area'] == 'DETENTION FACILITY')]['City'].value_counts()
# Out:
# City
# VISTA    33
# Name: count, dtype: int64

# %%
# Update the City field to 'SAN DIEGO' for rows where City is null, BCS Area is 'DETENTION FACILITY' and Beat is 21

v4.loc[(v4['City'].isnull()) & (v4['BCS Area'] == 'DETENTION FACILITY') & (v4['Beat'] == 21), 'City'] = 'SAN DIEGO'

# %%
# Update the City field to 'SAN DIEGO' for rows where City is null, BCS Area is 'DETENTION FACILITY' and Beat is 26

v4.loc[(v4['City'].isnull()) & (v4['BCS Area'] == 'DETENTION FACILITY') & (v4['Beat'] == 26), 'City'] = 'VISTA'

# %%
# adding city names for beat 21 detention facilities gave us 5 more rows

v4['City'].isnull().sum()
# Out:
# 41

# %%
# final dataframe of null 'City' value rows

v4[v4['City'].isnull()]
# Out:
#        Incident UID         Agency   Incident Date CIBRS Unique Offense ID  \
# 7            773065      SAN DIEGO     7/3/21 2:00       773065-13B-796976
# 8            804854      SAN DIEGO   8/13/21 21:00       804854-13B-829961
# 48          1895587        SHERIFF   1/10/21 19:57     1895587-13B-1685125
# 179          842006      SAN DIEGO    2/1/21 12:00       842006-11D-868919
# 251         1684372      SAN DIEGO     1/1/21 0:01     1684372-11A-1513584
# 375         1684372      SAN DIEGO     1/1/21 0:01     1684372-11C-1513584
# 4724         796100      SAN DIEGO     4/1/21 0:00       796100-36B-820804
# 4883         919885      SAN DIEGO   5/14/21 12:00       919885-11C-950669
# 5687         919885      SAN DIEGO   5/14/21 12:00       919885-11B-950669
# 5699        1072767      SAN DIEGO     5/1/21 0:01     1072767-11A-1110236
# 6103         722177      SAN DIEGO   4/23/21 20:37       722177-11D-743660
# 6927         745772      SAN DIEGO   6/19/21 21:00       745772-13C-768355
# 7791         748162      SAN DIEGO    6/19/21 1:00       748162-13B-770883
# 9371        1419460        SHERIFF    7/13/21 0:01     1419460-36B-1290607
# 13549        837521      SAN DIEGO    9/19/21 9:30       837521-13A-864174
# 13948       1689551        SHERIFF  10/30/21 12:00     1689551-11D-1517538
# 16431        921721  HARBOR POLICE  12/20/21 17:55       921721-13A-952559
# 17402        930219      SAN DIEGO  12/31/21 23:45       930219-13B-961470
# 18654        959623      SAN DIEGO   1/29/22 19:00       959623-13B-992675
# 18863       1428424      SAN DIEGO    1/8/22 20:00     1428424-13A-1298092
# 21180       1003699      SAN DIEGO   3/18/22 16:00     1003699-13B-1038662
# 21968       1001520      SAN DIEGO    3/20/22 0:01     1001520-13A-1036461
# 25839       1206340      SAN DIEGO   6/10/22 21:00     1206340-13A-1129387
# 28635       1333097      SAN DIEGO    9/12/22 4:14     1333097-11A-1239351
# 29862       1431856      SAN DIEGO  10/10/22 17:00     1431856-13C-1300848
# 30198       1433084      SAN DIEGO   10/1/22 18:48     1433084-13B-1301736
# 31776       1694000      SAN DIEGO  10/29/22 23:49     1694000-11A-1521091
# 31867       1468232      SAN DIEGO   11/14/22 1:00     1468232-13A-1332180
# 32704       2132256      SAN DIEGO  10/31/22 16:30     2132256-11D-1879608
# 37482       1682365      SAN DIEGO    2/28/23 0:01     1682365-13A-1512059
# 37982       1613883      SAN DIEGO    3/17/23 7:30     1613883-13B-1455500
# 40634       1706046      SAN DIEGO    5/29/23 0:00     1706046-13A-1530598
# 43812       1828579      SAN DIEGO    9/6/23 14:30     1828579-36B-1630626
# 44661       1827544      SAN DIEGO   8/14/23 21:00     1827544-11A-1629648
# 45318       1803562      SAN DIEGO   8/19/23 23:00     1803562-13B-1610643
# 49215       2273396      SAN DIEGO   12/25/23 9:00     2273396-13C-1998481
# 50912       2273396      SAN DIEGO   12/25/23 9:00     2273396-100-1998481
# 51971       2095716      SAN DIEGO   2/26/24 10:00     2095716-100-1851105
# 52992       2093592        SHERIFF   3/18/24 21:00     2093592-13A-1849246
# 54429       2114189      SAN DIEGO   3/17/24 12:00     2114189-11A-1865587
# 62085       2347759      SAN DIEGO     9/8/24 1:00     2347759-13A-2057984
#
#       CIBRS Offense Code      CIBRS Offense Description  Victim UID  \
# 7                    13B                 Simple Assault      796976
# 8                    13B                 Simple Assault      829961
# 48                   13B                 Simple Assault     1685125
# 179                  11D              Forcible Fondling      868919
# 251                  11A                  Forcible Rape     1513584
# 375                  11C  Sexual Assault With An Object     1513584
# 4724                 36B                 Statutory Rape      820804
# 4883                 11C  Sexual Assault With An Object      950669
# 5687                 11B                Forcible Sodomy      950669
# 5699                 11A                  Forcible Rape     1110236
# 6103                 11D              Forcible Fondling      743660
# 6927                 13C                   Intimidation      768355
# 7791                 13B                 Simple Assault      770883
# 9371                 36B                 Statutory Rape     1290607
# 13549                13A             Aggravated Assault      864174
# 13948                11D              Forcible Fondling     1517538
# 16431                13A             Aggravated Assault      952559
# 17402                13B                 Simple Assault      961470
# 18654                13B                 Simple Assault      992675
# 18863                13A             Aggravated Assault     1298092
# 21180                13B                 Simple Assault     1038662
# 21968                13A             Aggravated Assault     1036461
# 25839                13A             Aggravated Assault     1129387
# 28635                11A                  Forcible Rape     1239351
# 29862                13C                   Intimidation     1300848
# 30198                13B                 Simple Assault     1301736
# 31776                11A                  Forcible Rape     1521091
# 31867                13A             Aggravated Assault     1332180
# 32704                11D              Forcible Fondling     1879608
# 37482                13A             Aggravated Assault     1512059
# 37982                13B                 Simple Assault     1455500
# 40634                13A             Aggravated Assault     1530598
# 43812                36B                 Statutory Rape     1630626
# 44661                11A                  Forcible Rape     1629648
# 45318                13B                 Simple Assault     1610643
# 49215                13C                   Intimidation     1998481
# 50912                100            Kidnaping/Abduction     1998481
# 51971                100            Kidnaping/Abduction     1851105
# 52992                13A             Aggravated Assault     1849246
# 54429                11A                  Forcible Rape     1865587
# 62085                13A             Aggravated Assault     2057984
#
#       Victim Category  Victim Age    Overall Race City  Zip Code  \
# 7                   I        18.0        HISPANIC  NaN       NaN
# 8                   I        40.0           WHITE  NaN       NaN
# 48                  I         0.0        HISPANIC  NaN       NaN
# 179                 I        10.0           WHITE  NaN       NaN
# 251                 I        20.0           WHITE  NaN       NaN
# 375                 I        20.0           WHITE  NaN       NaN
# 4724                I        14.0           BLACK  NaN       NaN
# 4883                I         7.0           BLACK  NaN       NaN
# 5687                I         7.0           BLACK  NaN       NaN
# 5699                I        18.0           ASIAN  NaN       NaN
# 6103                I        15.0           WHITE  NaN       NaN
# 6927                I        37.0           WHITE  NaN       NaN
# 7791                I        19.0           OTHER  NaN       NaN
# 9371                I        14.0        HISPANIC  NaN       NaN
# 13549               I        29.0           WHITE  NaN       NaN
# 13948               I         9.0           BLACK  NaN       NaN
# 16431               I        43.0           WHITE  NaN       NaN
# 17402               I        47.0           WHITE  NaN       NaN
# 18654               I        31.0        HISPANIC  NaN       NaN
# 18863               I        37.0  MIDDLE EASTERN  NaN       NaN
# 21180               I        24.0        HISPANIC  NaN       NaN
# 21968               I        32.0           WHITE  NaN       NaN
# 25839               I        52.0           BLACK  NaN       NaN
# 28635               I        24.0           WHITE  NaN       NaN
# 29862               I        26.0           BLACK  NaN       NaN
# 30198               I        21.0           WHITE  NaN       NaN
# 31776               I        15.0           BLACK  NaN       NaN
# 31867               I        23.0        HISPANIC  NaN       NaN
# 32704               I        18.0        HISPANIC  NaN       NaN
# 37482               I         0.0        HISPANIC  NaN       NaN
# 37982               I        54.0           WHITE  NaN       NaN
# 40634               I        36.0           WHITE  NaN       NaN
# 43812               I        15.0        HISPANIC  NaN       NaN
# 44661               I        16.0        HISPANIC  NaN       NaN
# 45318               I        38.0        HISPANIC  NaN       NaN
# 49215               I        33.0           WHITE  NaN       NaN
# 50912               I        33.0           WHITE  NaN       NaN
# 51971               I        17.0           BLACK  NaN       NaN
# 52992               I        36.0        HISPANIC  NaN       NaN
# 54429               I        33.0           WHITE  NaN       NaN
# 62085               I        24.0        HISPANIC  NaN       NaN
#
#        Census Tract                  CIBRS Status  Domestic Violence Incident  \
# 7               NaN    ProcessingComplete - Valid                        True
# 8               NaN    ProcessingComplete - Valid                        True
# 48              NaN    ProcessingComplete - Valid                       False
# 179             NaN    ProcessingComplete - Valid                       False
# 251             NaN    ProcessingComplete - Valid                       False
# 375             NaN    ProcessingComplete - Valid                       False
# 4724            NaN    ProcessingComplete - Valid                       False
# 4883            NaN    ProcessingComplete - Valid                       False
# 5687            NaN    ProcessingComplete - Valid                       False
# 5699            NaN  ProcessingComplete - Invalid                       False
# 6103            NaN    ProcessingComplete - Valid                       False
# 6927            NaN  ProcessingComplete - Invalid                        True
# 7791            NaN    ProcessingComplete - Valid                        True
# 9371            NaN    ProcessingComplete - Valid                       False
# 13549           NaN    ProcessingComplete - Valid                       False
# 13948           NaN    ProcessingComplete - Valid                       False
# 16431           NaN    ProcessingComplete - Valid                       False
# 17402           NaN  ProcessingComplete - Invalid                        True
# 18654           NaN    ProcessingComplete - Valid                        True
# 18863           NaN  ProcessingComplete - Invalid                        True
# 21180           NaN    ProcessingComplete - Valid                        True
# 21968           NaN    ProcessingComplete - Valid                        True
# 25839           NaN    ProcessingComplete - Valid                       False
# 28635           NaN    ProcessingComplete - Valid                       False
# 29862           NaN  ProcessingComplete - Invalid                        True
# 30198           NaN  ProcessingComplete - Invalid                        True
# 31776           NaN    ProcessingComplete - Valid                       False
# 31867           NaN  ProcessingComplete - Invalid                        True
# 32704           NaN  ProcessingComplete - Invalid                       False
# 37482           NaN  ProcessingComplete - Invalid                       False
# 37982           NaN  ProcessingComplete - Invalid                       False
# 40634           NaN    ProcessingComplete - Valid                        True
# 43812           NaN    ProcessingComplete - Valid                       False
# 44661           NaN    ProcessingComplete - Valid                        True
# 45318           NaN  ProcessingComplete - Invalid                        True
# 49215           NaN  ProcessingComplete - Invalid                        True
# 50912           NaN  ProcessingComplete - Invalid                        True
# 51971           NaN    ProcessingComplete - Valid                       False
# 52992           NaN  ProcessingComplete - Invalid                        True
# 54429           NaN  ProcessingComplete - Invalid                       False
# 62085           NaN    ProcessingComplete - Valid                        True
#
#        Beat           BCS Area
# 7       999                NaN
# 8       999                NaN
# 48        7  NON-CONTRACT CITY
# 179     999                NaN
# 251     999                NaN
# 375     999                NaN
# 4724    999                NaN
# 4883    999                NaN
# 5687    999                NaN
# 5699    999                NaN
# 6103    999                NaN
# 6927    999                NaN
# 7791    999                NaN
# 9371      0  NON-CONTRACT CITY
# 13549   999                NaN
# 13948     0  NON-CONTRACT CITY
# 16431   550                NaN
# 17402   999                NaN
# 18654   999                NaN
# 18863   999                NaN
# 21180   999                NaN
# 21968   999                NaN
# 25839   999                NaN
# 28635   999                NaN
# 29862   999                NaN
# 30198   999                NaN
# 31776   999                NaN
# 31867   999                NaN
# 32704   999                NaN
# 37482   999                NaN
# 37982   999                NaN
# 40634   999                NaN
# 43812   999                NaN
# 44661   999                NaN
# 45318   999                NaN
# 49215   999                NaN
# 50912   999                NaN
# 51971   999                NaN
# 52992     0  NON-CONTRACT CITY
# 54429   999                NaN
# 62085   999                NaN

# %%
# v4crimedata

v4.to_csv('v4crimedata.csv', index=False)

# %%
# create download link for v4 of data

def create_download_link(filename):
    return HTML(f'<a href="{filename}" download>Download {filename}</a>')

create_download_link('v4crimedata.csv')
# Out:
# <a href="v4crimedata.csv" download>Download v4crimedata.csv</a>
